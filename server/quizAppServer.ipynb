# %%
# !git clone https://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@github.com/ahmedjamshed/QuizApp.git
# Out:
# Cloning into 'QuizApp'...
# remote: Enumerating objects: 1244, done.
# remote: Counting objects: 100% (1244/1244), done.
# remote: Compressing objects: 100% (751/751), done.
# remote: Total 1244 (delta 624), reused 965 (delta 379), pack-reused 0
# Receiving objects: 100% (1244/1244), 1.75 MiB | 11.80 MiB/s, done.
# Resolving deltas: 100% (624/624), done.

# %%
# %cd QuizApp/server/
# Out:
# /content/QuizApp/server

# %%
# !pip install -r requirements.txt
# Out:
# Collecting en-core-web-sm@ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl (13.9 MB)
#      |████████████████████████████████| 13.9 MB 5.4 MB/s
# Collecting asgiref==3.4.1
#   Downloading asgiref-3.4.1-py3-none-any.whl (25 kB)
# Collecting autopep8==1.5.7
#   Downloading autopep8-1.5.7-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 2.7 MB/s
# Collecting beautifulsoup4==4.10.0
#   Downloading beautifulsoup4-4.10.0-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 4.0 MB/s
# Collecting blis==0.7.5
#   Downloading blis-0.7.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 47.7 MB/s
# Requirement already satisfied: bs4==0.0.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 5)) (0.0.1)
# Requirement already satisfied: cachetools==4.2.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 6)) (4.2.4)
# Collecting catalogue==2.0.6
#   Downloading catalogue-2.0.6-py3-none-any.whl (17 kB)
# Collecting certifi==2021.5.30
#   Downloading certifi-2021.5.30-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 47.3 MB/s
# Collecting charset-normalizer==2.0.6
#   Downloading charset_normalizer-2.0.6-py3-none-any.whl (37 kB)
# Collecting click==8.0.1
#   Downloading click-8.0.1-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 6.4 MB/s
# Collecting cycler==0.10.0
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: cymem==2.0.6 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 12)) (2.0.6)
# Requirement already satisfied: dill==0.3.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 13)) (0.3.4)
# Collecting fastapi==0.68.0
#   Downloading fastapi-0.68.0-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 676 kB/s
# Collecting filelock==3.3.0
#   Downloading filelock-3.3.0-py3-none-any.whl (9.7 kB)
# Collecting Flask==1.1.1
#   Downloading Flask-1.1.1-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 2.9 MB/s
# Collecting google-api-core==2.1.0
#   Downloading google_api_core-2.1.0-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.3 MB/s
# Collecting google-auth==2.2.1
#   Downloading google_auth-2.2.1-py2.py3-none-any.whl (153 kB)
#      |████████████████████████████████| 153 kB 46.2 MB/s
# Collecting google-auth-httplib2==0.1.0
#   Downloading google_auth_httplib2-0.1.0-py2.py3-none-any.whl (9.3 kB)
# Collecting google-cloud-core==2.1.0
#   Downloading google_cloud_core-2.1.0-py2.py3-none-any.whl (27 kB)
# Collecting google-cloud-storage==1.42.3
#   Downloading google_cloud_storage-1.42.3-py2.py3-none-any.whl (105 kB)
#      |████████████████████████████████| 105 kB 47.9 MB/s
# Collecting google-cloud-vision==2.4.4
#   Downloading google_cloud_vision-2.4.4-py2.py3-none-any.whl (369 kB)
#      |████████████████████████████████| 369 kB 46.5 MB/s
# Collecting google-crc32c==1.3.0
#   Downloading google_crc32c-1.3.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38 kB)
# Collecting google-resumable-media==2.0.3
#   Downloading google_resumable_media-2.0.3-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 4.0 MB/s
# Requirement already satisfied: googleapis-common-protos==1.53.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 26)) (1.53.0)
# Collecting grpcio==1.41.0
#   Downloading grpcio-1.41.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.9 MB)
#      |████████████████████████████████| 3.9 MB 33.5 MB/s
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 48.9 MB/s
# Collecting h11==0.12.0
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.1 MB/s
# Collecting httplib2==0.20.1
#   Downloading httplib2-0.20.1-py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 5.4 MB/s
# Collecting huggingface-hub==0.0.19
#   Downloading huggingface_hub-0.0.19-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 4.7 MB/s
# Collecting idna==3.2
#   Downloading idna-3.2-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 5.8 MB/s
# Requirement already satisfied: itsdangerous==1.1.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 33)) (1.1.0)
# Collecting Jinja2==2.10.1
#   Downloading Jinja2-2.10.1-py2.py3-none-any.whl (124 kB)
#      |████████████████████████████████| 124 kB 54.9 MB/s
# Collecting joblib==1.0.1
#   Downloading joblib-1.0.1-py3-none-any.whl (303 kB)
#      |████████████████████████████████| 303 kB 46.9 MB/s
# Requirement already satisfied: kiwisolver==1.3.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 36)) (1.3.2)
# Collecting langcodes==3.3.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 45.5 MB/s
# Collecting MarkupSafe==1.1.1
#   Downloading MarkupSafe-1.1.1-cp37-cp37m-manylinux2010_x86_64.whl (33 kB)
# Collecting matplotlib==3.4.3
#   Downloading matplotlib-3.4.3-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 23.2 MB/s
# Requirement already satisfied: murmurhash==1.0.6 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 40)) (1.0.6)
# Collecting nest-asyncio==1.5.1
#   Downloading nest_asyncio-1.5.1-py3-none-any.whl (5.0 kB)
# Collecting nlp==0.4.0
#   Downloading nlp-0.4.0-py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 36.2 MB/s
# Collecting nltk==3.3
#   Downloading nltk-3.3.0.zip (1.4 MB)
#      |████████████████████████████████| 1.4 MB 43.3 MB/s
# Collecting numpy==1.21.2
#   Downloading numpy-1.21.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 36.5 MB/s
# Collecting packaging==21.0
#   Downloading packaging-21.0-py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 5.0 MB/s
# Collecting pandas==1.3.3
#   Downloading pandas-1.3.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 30.9 MB/s
# Collecting pathy==0.6.1
#   Downloading pathy-0.6.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.3 MB/s
# Collecting Pillow==8.3.2
#   Downloading Pillow-8.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 33.6 MB/s
# Requirement already satisfied: preshed==3.0.6 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 49)) (3.0.6)
# Collecting proto-plus==1.19.2
#   Downloading proto_plus-1.19.2-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 1.5 MB/s
# Collecting protobuf==3.18.1
#   Downloading protobuf-3.18.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 52.5 MB/s
# Collecting pyarrow==5.0.0
#   Downloading pyarrow-5.0.0-cp37-cp37m-manylinux2014_x86_64.whl (23.6 MB)
#      |████████████████████████████████| 23.6 MB 54.9 MB/s
# Requirement already satisfied: pyasn1==0.4.8 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 53)) (0.4.8)
# Requirement already satisfied: pyasn1-modules==0.2.8 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 54)) (0.2.8)
# Collecting pycodestyle==2.7.0
#   Downloading pycodestyle-2.7.0-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 552 kB/s
# Collecting pydantic==1.8.2
#   Downloading pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 34.8 MB/s
# Collecting pyngrok==5.1.0
#   Downloading pyngrok-5.1.0.tar.gz (745 kB)
#      |████████████████████████████████| 745 kB 47.9 MB/s
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 5.6 MB/s
# Requirement already satisfied: python-dateutil==2.8.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 59)) (2.8.2)
# Collecting python-dotenv==0.19.1
#   Downloading python_dotenv-0.19.1-py2.py3-none-any.whl (17 kB)
# Collecting pytz==2021.3
#   Downloading pytz-2021.3-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 45.0 MB/s
# Collecting PyYAML==5.4.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 49.1 MB/s
# Collecting regex==2021.9.30
#   Downloading regex-2021.9.30-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (747 kB)
#      |████████████████████████████████| 747 kB 47.1 MB/s
# Collecting requests==2.26.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 764 kB/s
# Collecting rsa==4.7.2
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting sacremoses==0.0.46
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 47.5 MB/s
# Collecting scikit-learn==1.0
#   Downloading scikit_learn-1.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (23.1 MB)
#      |████████████████████████████████| 23.1 MB 1.6 MB/s
# Collecting scipy==1.7.1
#   Downloading scipy-1.7.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (28.5 MB)
#      |████████████████████████████████| 28.5 MB 47.9 MB/s
# Collecting semantic-version==2.8.5
#   Downloading semantic_version-2.8.5-py2.py3-none-any.whl (15 kB)
# Collecting sense2vec==2.0.0
#   Downloading sense2vec-2.0.0-py2.py3-none-any.whl (39 kB)
# Collecting sentencepiece==0.1.96
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 50.2 MB/s
# Collecting setuptools-rust==0.12.1
#   Downloading setuptools_rust-0.12.1-py3-none-any.whl (22 kB)
# Collecting six==1.16.0
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: smart-open==5.2.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 74)) (5.2.1)
# Collecting soupsieve==2.2.1
#   Downloading soupsieve-2.2.1-py3-none-any.whl (33 kB)
# Collecting spacy==3.2.1
#   Downloading spacy-3.2.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      |████████████████████████████████| 6.0 MB 35.9 MB/s
# Collecting spacy-legacy==3.0.8
#   Downloading spacy_legacy-3.0.8-py2.py3-none-any.whl (14 kB)
# Collecting spacy-loggers==1.0.1
#   Downloading spacy_loggers-1.0.1-py3-none-any.whl (7.0 kB)
# Collecting spacy-wordnet==0.0.5
#   Downloading spacy_wordnet-0.0.5-py2.py3-none-any.whl (650 kB)
#      |████████████████████████████████| 650 kB 51.3 MB/s
# Collecting srsly==2.4.2
#   Downloading srsly-2.4.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (451 kB)
#      |████████████████████████████████| 451 kB 48.2 MB/s
# Collecting starlette==0.14.2
#   Downloading starlette-0.14.2-py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 6.4 MB/s
# Collecting thinc==8.0.13
#   Downloading thinc-8.0.13-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (628 kB)
#      |████████████████████████████████| 628 kB 41.7 MB/s
# Requirement already satisfied: threadpoolctl==3.0.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 83)) (3.0.0)
# Collecting tokenizers==0.10.3
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 36.7 MB/s
# Requirement already satisfied: toml==0.10.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 85)) (0.10.2)
# Requirement already satisfied: tomli==1.2.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 86)) (1.2.2)
# Collecting torch==1.9.1
#   Downloading torch-1.9.1-cp37-cp37m-manylinux1_x86_64.whl (831.4 MB)
#      |████████████████████████████████| 831.4 MB 6.8 kB/s
# Collecting torchvision==0.10.1
#   Downloading torchvision-0.10.1-cp37-cp37m-manylinux1_x86_64.whl (22.1 MB)
#      |████████████████████████████████| 22.1 MB 11.7 MB/s
# Requirement already satisfied: tqdm==4.62.3 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 89)) (4.62.3)
# Collecting transformers==4.11.3
#   Downloading transformers-4.11.3-py3-none-any.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 36.3 MB/s
# Collecting typer==0.4.0
#   Downloading typer-0.4.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: typing-extensions==3.10.0.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 92)) (3.10.0.2)
# Collecting uritemplate==4.1.1
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Collecting uvicorn==0.14.0
#   Downloading uvicorn-0.14.0-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 6.0 MB/s
# Requirement already satisfied: wasabi==0.8.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 95)) (0.8.2)
# Collecting Werkzeug==0.15.5
#   Downloading Werkzeug-0.15.5-py2.py3-none-any.whl (328 kB)
#      |████████████████████████████████| 328 kB 46.2 MB/s
# Collecting wikipedia==1.4.0
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
# Collecting wn==0.0.23
#   Downloading wn-0.0.23.tar.gz (31.6 MB)
#      |████████████████████████████████| 31.6 MB 56.9 MB/s
# Collecting xxhash==2.0.2
#   Downloading xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243 kB)
#      |████████████████████████████████| 243 kB 45.1 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue==2.0.6->-r requirements.txt (line 7)) (3.6.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from click==8.0.1->-r requirements.txt (line 10)) (4.8.2)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core==2.1.0->-r requirements.txt (line 18)) (57.4.0)
# Requirement already satisfied: google-api-core[grpc]<3.0.0dev,>=1.26.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-vision==2.4.4->-r requirements.txt (line 23)) (1.26.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests==2.26.0->-r requirements.txt (line 64)) (1.24.3)
# Collecting google-api-core[grpc]<3.0.0dev,>=1.26.0
#   Downloading google_api_core-2.3.2-py2.py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 48.0 MB/s
#   Downloading google_api_core-2.3.0-py2.py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 46.7 MB/s
#   Downloading google_api_core-2.2.2-py2.py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 4.5 MB/s
#   Downloading google_api_core-2.2.1-py2.py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 4.3 MB/s
#   Downloading google_api_core-2.2.0-py2.py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 4.8 MB/s
#   Downloading google_api_core-2.1.1-py2.py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 3.9 MB/s
# Building wheels for collected packages: nltk, pyngrok, wikipedia, wn
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.3-py3-none-any.whl size=1394485 sha256=b637fb411d0e70c45bc6de883c90f8bdc63a06eccc117aa06f2ae46b2e7797fc
#   Stored in directory: /root/.cache/pip/wheels/9b/fd/0c/d92302c876e5de87ebd7fc0979d82edb93e2d8d768bf71fac4
#   Building wheel for pyngrok (setup.py) ... done
#   Created wheel for pyngrok: filename=pyngrok-5.1.0-py3-none-any.whl size=19006 sha256=154e922defde9f386a14eb3a124b86dbf5589a52f0d483f135ce07ac095d9640
#   Stored in directory: /root/.cache/pip/wheels/bf/e6/af/ccf6598ecefecd44104069371795cb9b3afbcd16987f6ccfb3
#   Building wheel for wikipedia (setup.py) ... done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11696 sha256=62bf3a05b4a9a6f08767538a00ccaaf2ba10be3468a0faa1017a3145823434b1
#   Stored in directory: /root/.cache/pip/wheels/15/93/6d/5b2c68b8a64c7a7a04947b4ed6d89fb557dcc6bc27d1d7f3ba
#   Building wheel for wn (setup.py) ... done
#   Created wheel for wn: filename=wn-0.0.23-py3-none-any.whl size=31792926 sha256=b12277f1978eeefa26975ec1d066264ca4492b65575699294a10a9c70850c7a5
#   Stored in directory: /root/.cache/pip/wheels/ec/47/17/409766c99dd470f34c512000b90b83f34747c2c975769654d7
# Successfully built nltk pyngrok wikipedia wn
# Installing collected packages: rsa, protobuf, numpy, idna, click, charset-normalizer, certifi, catalogue, typer, srsly, six, requests, pyparsing, pydantic, MarkupSafe, google-auth, blis, thinc, spacy-loggers, spacy-legacy, soupsieve, regex, PyYAML, pytz, pathy, packaging, langcodes, joblib, Jinja2, grpcio, google-crc32c, google-api-core, filelock, xxhash, Werkzeug, torch, tokenizers, starlette, spacy, semantic-version, scipy, sacremoses, pycodestyle, pyarrow, proto-plus, Pillow, pandas, nltk, huggingface-hub, httplib2, h11, google-resumable-media, google-cloud-core, cycler, beautifulsoup4, asgiref, wn, wikipedia, uvicorn, uritemplate, transformers, torchvision, spacy-wordnet, setuptools-rust, sentencepiece, sense2vec, scikit-learn, python-dotenv, pyngrok, nlp, nest-asyncio, matplotlib, gunicorn, google-cloud-vision, google-cloud-storage, google-auth-httplib2, Flask, fastapi, en-core-web-sm, autopep8
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.8
#     Uninstalling rsa-4.8:
#       Successfully uninstalled rsa-4.8
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: idna
#     Found existing installation: idna 2.10
#     Uninstalling idna-2.10:
#       Successfully uninstalled idna-2.10
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 2.0.9
#     Uninstalling charset-normalizer-2.0.9:
#       Successfully uninstalled charset-normalizer-2.0.9
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2021.10.8
#     Uninstalling certifi-2021.10.8:
#       Successfully uninstalled certifi-2021.10.8
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 1.0.0
#     Uninstalling catalogue-1.0.0:
#       Successfully uninstalled catalogue-1.0.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 1.0.5
#     Uninstalling srsly-1.0.5:
#       Successfully uninstalled srsly-1.0.5
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.6
#     Uninstalling pyparsing-3.0.6:
#       Successfully uninstalled pyparsing-3.0.6
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.0.1
#     Uninstalling MarkupSafe-2.0.1:
#       Successfully uninstalled MarkupSafe-2.0.1
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 1.35.0
#     Uninstalling google-auth-1.35.0:
#       Successfully uninstalled google-auth-1.35.0
#   Attempting uninstall: blis
#     Found existing installation: blis 0.4.1
#     Uninstalling blis-0.4.1:
#       Successfully uninstalled blis-0.4.1
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Attempting uninstall: regex
#     Found existing installation: regex 2019.12.20
#     Uninstalling regex-2019.12.20:
#       Successfully uninstalled regex-2019.12.20
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2018.9
#     Uninstalling pytz-2018.9:
#       Successfully uninstalled pytz-2018.9
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.42.0
#     Uninstalling grpcio-1.42.0:
#       Successfully uninstalled grpcio-1.42.0
#   Attempting uninstall: google-api-core
#     Found existing installation: google-api-core 1.26.3
#     Uninstalling google-api-core-1.26.3:
#       Successfully uninstalled google-api-core-1.26.3
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.4.0
#     Uninstalling filelock-3.4.0:
#       Successfully uninstalled filelock-3.4.0
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 1.0.1
#     Uninstalling Werkzeug-1.0.1:
#       Successfully uninstalled Werkzeug-1.0.1
#   Attempting uninstall: torch
#     Found existing installation: torch 1.10.0+cu111
#     Uninstalling torch-1.10.0+cu111:
#       Successfully uninstalled torch-1.10.0+cu111
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 3.0.0
#     Uninstalling pyarrow-3.0.0:
#       Successfully uninstalled pyarrow-3.0.0
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.5
#     Uninstalling pandas-1.1.5:
#       Successfully uninstalled pandas-1.1.5
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
#   Attempting uninstall: httplib2
#     Found existing installation: httplib2 0.17.4
#     Uninstalling httplib2-0.17.4:
#       Successfully uninstalled httplib2-0.17.4
#   Attempting uninstall: google-resumable-media
#     Found existing installation: google-resumable-media 0.4.1
#     Uninstalling google-resumable-media-0.4.1:
#       Successfully uninstalled google-resumable-media-0.4.1
#   Attempting uninstall: google-cloud-core
#     Found existing installation: google-cloud-core 1.0.3
#     Uninstalling google-cloud-core-1.0.3:
#       Successfully uninstalled google-cloud-core-1.0.3
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
#   Attempting uninstall: uritemplate
#     Found existing installation: uritemplate 3.0.1
#     Uninstalling uritemplate-3.0.1:
#       Successfully uninstalled uritemplate-3.0.1
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.11.1+cu111
#     Uninstalling torchvision-0.11.1+cu111:
#       Successfully uninstalled torchvision-0.11.1+cu111
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.1
#     Uninstalling scikit-learn-1.0.1:
#       Successfully uninstalled scikit-learn-1.0.1
#   Attempting uninstall: nest-asyncio
#     Found existing installation: nest-asyncio 1.5.4
#     Uninstalling nest-asyncio-1.5.4:
#       Successfully uninstalled nest-asyncio-1.5.4
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
#   Attempting uninstall: google-cloud-storage
#     Found existing installation: google-cloud-storage 1.18.1
#     Uninstalling google-cloud-storage-1.18.1:
#       Successfully uninstalled google-cloud-storage-1.18.1
#   Attempting uninstall: google-auth-httplib2
#     Found existing installation: google-auth-httplib2 0.0.4
#     Uninstalling google-auth-httplib2-0.0.4:
#       Successfully uninstalled google-auth-httplib2-0.0.4
#   Attempting uninstall: Flask
#     Found existing installation: Flask 1.1.4
#     Uninstalling Flask-1.1.4:
#       Successfully uninstalled Flask-1.1.4
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 2.2.5
#     Uninstalling en-core-web-sm-2.2.5:
#       Successfully uninstalled en-core-web-sm-2.2.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.3.post1 requires numpy<1.20,>=1.16.0, but you have numpy 1.21.2 which is incompatible.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.9.1 which is incompatible.
# torchaudio 0.10.0+cu111 requires torch==1.10.0, but you have torch 1.9.1 which is incompatible.
# nbclient 0.5.9 requires jupyter-client>=6.1.5, but you have jupyter-client 5.3.5 which is incompatible.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.3.3 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.26.0 which is incompatible.
# google-colab 1.0.0 requires six~=1.15.0, but you have six 1.16.0 which is incompatible.
# google-cloud-translate 1.5.0 requires google-api-core[grpc]<2.0.0dev,>=1.6.0, but you have google-api-core 2.1.0 which is incompatible.
# google-cloud-translate 1.5.0 requires google-cloud-core<2.0dev,>=1.0.0, but you have google-cloud-core 2.1.0 which is incompatible.
# google-cloud-language 1.2.0 requires google-api-core[grpc]<2.0.0dev,>=1.6.0, but you have google-api-core 2.1.0 which is incompatible.
# google-cloud-firestore 1.7.0 requires google-api-core[grpc]<2.0.0dev,>=1.14.0, but you have google-api-core 2.1.0 which is incompatible.
# google-cloud-firestore 1.7.0 requires google-cloud-core<2.0dev,>=1.0.3, but you have google-cloud-core 2.1.0 which is incompatible.
# google-cloud-datastore 1.8.0 requires google-api-core[grpc]<2.0.0dev,>=1.6.0, but you have google-api-core 2.1.0 which is incompatible.
# google-cloud-datastore 1.8.0 requires google-cloud-core<2.0dev,>=1.0.0, but you have google-cloud-core 2.1.0 which is incompatible.
# google-cloud-bigquery 1.21.0 requires google-cloud-core<2.0dev,>=1.0.3, but you have google-cloud-core 2.1.0 which is incompatible.
# google-cloud-bigquery 1.21.0 requires google-resumable-media!=0.4.0,<0.5.0dev,>=0.3.1, but you have google-resumable-media 2.0.3 which is incompatible.
# google-cloud-bigquery-storage 1.1.0 requires google-api-core[grpc]<2.0.0dev,>=1.14.0, but you have google-api-core 2.1.0 which is incompatible.
# google-api-python-client 1.12.8 requires google-api-core<2dev,>=1.21.0, but you have google-api-core 2.1.0 which is incompatible.
# google-api-python-client 1.12.8 requires uritemplate<4dev,>=3.0.0, but you have uritemplate 4.1.1 which is incompatible.
# firebase-admin 4.4.0 requires google-api-core[grpc]<2.0.0dev,>=1.14.0; platform_python_implementation != "PyPy", but you have google-api-core 2.1.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed Flask-1.1.1 Jinja2-2.10.1 MarkupSafe-1.1.1 Pillow-8.3.2 PyYAML-5.4.1 Werkzeug-0.15.5 asgiref-3.4.1 autopep8-1.5.7 beautifulsoup4-4.10.0 blis-0.7.5 catalogue-2.0.6 certifi-2021.5.30 charset-normalizer-2.0.6 click-8.0.1 cycler-0.10.0 en-core-web-sm-3.2.0 fastapi-0.68.0 filelock-3.3.0 google-api-core-2.1.0 google-auth-2.2.1 google-auth-httplib2-0.1.0 google-cloud-core-2.1.0 google-cloud-storage-1.42.3 google-cloud-vision-2.4.4 google-crc32c-1.3.0 google-resumable-media-2.0.3 grpcio-1.41.0 gunicorn-19.9.0 h11-0.12.0 httplib2-0.20.1 huggingface-hub-0.0.19 idna-3.2 joblib-1.0.1 langcodes-3.3.0 matplotlib-3.4.3 nest-asyncio-1.5.1 nlp-0.4.0 nltk-3.3 numpy-1.21.2 packaging-21.0 pandas-1.3.3 pathy-0.6.1 proto-plus-1.19.2 protobuf-3.18.1 pyarrow-5.0.0 pycodestyle-2.7.0 pydantic-1.8.2 pyngrok-5.1.0 pyparsing-2.4.7 python-dotenv-0.19.1 pytz-2021.3 regex-2021.9.30 requests-2.26.0 rsa-4.7.2 sacremoses-0.0.46 scikit-learn-1.0 scipy-1.7.1 semantic-version-2.8.5 sense2vec-2.0.0 sentencepiece-0.1.96 setuptools-rust-0.12.1 six-1.16.0 soupsieve-2.2.1 spacy-3.2.1 spacy-legacy-3.0.8 spacy-loggers-1.0.1 spacy-wordnet-0.0.5 srsly-2.4.2 starlette-0.14.2 thinc-8.0.13 tokenizers-0.10.3 torch-1.9.1 torchvision-0.10.1 transformers-4.11.3 typer-0.4.0 uritemplate-4.1.1 uvicorn-0.14.0 wikipedia-1.4.0 wn-0.0.23 xxhash-2.0.2

# %%
# !pip install -e git+https://github.com/ahmedjamshed/question_generation.git@0.4.0#egg=question_generation
# Out:
# Obtaining question_generation from git+https://github.com/ahmedjamshed/question_generation.git@0.4.0#egg=question_generation
#   Cloning https://github.com/ahmedjamshed/question_generation.git (to revision 0.4.0) to ./src/question-generation
#   Running command git clone -q https://github.com/ahmedjamshed/question_generation.git /content/QuizApp/server/src/question-generation
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from question_generation) (4.11.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from question_generation) (3.3)
# Requirement already satisfied: nlp>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from question_generation) (0.4.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from question_generation) (1.9.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from nlp>=0.2.0->question_generation) (0.3.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from nlp>=0.2.0->question_generation) (3.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from nlp>=0.2.0->question_generation) (1.21.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from nlp>=0.2.0->question_generation) (1.3.3)
# Requirement already satisfied: pyarrow>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from nlp>=0.2.0->question_generation) (5.0.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from nlp>=0.2.0->question_generation) (2.0.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from nlp>=0.2.0->question_generation) (2.26.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from nlp>=0.2.0->question_generation) (4.62.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->nlp>=0.2.0->question_generation) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->nlp>=0.2.0->question_generation) (1.24.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->nlp>=0.2.0->question_generation) (2.0.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->nlp>=0.2.0->question_generation) (3.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers>=3.0.0->question_generation) (4.8.2)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers>=3.0.0->question_generation) (0.10.3)
# Requirement already satisfied: huggingface-hub>=0.0.17 in /usr/local/lib/python3.7/dist-packages (from transformers>=3.0.0->question_generation) (0.0.19)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers>=3.0.0->question_generation) (5.4.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers>=3.0.0->question_generation) (2021.9.30)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers>=3.0.0->question_generation) (21.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers>=3.0.0->question_generation) (0.0.46)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.17->transformers>=3.0.0->question_generation) (3.10.0.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers>=3.0.0->question_generation) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers>=3.0.0->question_generation) (3.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->question_generation) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->nlp>=0.2.0->question_generation) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->nlp>=0.2.0->question_generation) (2021.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=3.0.0->question_generation) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=3.0.0->question_generation) (8.0.1)
# Installing collected packages: question-generation
#   Running setup.py develop for question-generation
# Successfully installed question-generation-0.4.0

# %%
import requests
import tarfile

url = "https://github.com/explosion/sense2vec/releases/download/v1.0.0/s2v_reddit_2015_md.tar.gz"
response = requests.get(url, stream=True)
file = tarfile.open(fileobj=response.raw, mode="r|gz")
file.extractall(path=".")
print("end")
# Out:
# end

# %%
# !python -m nltk.downloader wordnet
# !python -m nltk.downloader punkt
# Out:
# /usr/lib/python3.7/runpy.py:125: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# /usr/lib/python3.7/runpy.py:125: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="/content/QuizApp/server/keyFile.json"

# %%
# !python main.py
# Out:
# Downloading: 100% 90.0/90.0 [00:00<00:00, 39.0kB/s]
# Downloading: 100% 0.99k/0.99k [00:00<00:00, 725kB/s]
# Downloading: 100% 773k/773k [00:00<00:00, 5.04MB/s]
# Downloading: 100% 31.0/31.0 [00:00<00:00, 23.9kB/s]
# Downloading: 100% 65.0/65.0 [00:00<00:00, 49.0kB/s]
# Downloading: 100% 231M/231M [00:06<00:00, 36.9MB/s]
# Downloading: 100% 90.0/90.0 [00:00<00:00, 93.7kB/s]
# Downloading: 100% 656/656 [00:00<00:00, 540kB/s]
# Downloading: 100% 773k/773k [00:00<00:00, 5.36MB/s]
# Downloading: 100% 31.0/31.0 [00:00<00:00, 25.7kB/s]
# Downloading: 100% 65.0/65.0 [00:00<00:00, 60.0kB/s]
# Downloading: 100% 231M/231M [00:06<00:00, 37.6MB/s]
# Public URL: http://6adc-35-188-92-19.ngrok.io
# INFO:     Started server process [246]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     115.186.139.232:0 - "POST /generateQuestions HTTP/1.1" 200 OK
# INFO:     115.186.139.232:0 - "POST /generateQuestions HTTP/1.1" 200 OK
# INFO:     115.186.139.232:0 - "POST /generateQuestions HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [246]
